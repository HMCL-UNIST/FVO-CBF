# %%
# --- Ensure working directory is project root (contains 'parameter/') ---
import os
if not os.path.isdir('parameter') and os.path.isdir('../parameter'):
    os.chdir('..')

# %%
import numpy as np
import json

# %%
def create_safe_initial_conditions(N_AGENTS, V_CONST, critical_distance, desired_distance,
                                   margin, class_k1, class_k2,
                                   position_range=(-50, 50), max_attempts=10000):
    """
    Generate a random initial state matrix such that every CBF method
    (VO, FVO, HO) is feasible at t=0.
    """
    for attempt in range(max_attempts):
        initial_states_matrix = np.zeros((5, N_AGENTS))

        px = np.random.uniform(position_range[0], position_range[1], size=N_AGENTS)
        py = np.random.uniform(position_range[0], position_range[1], size=N_AGENTS)
        theta = np.random.uniform(0, 2 * np.pi, size=N_AGENTS)

        initial_states_matrix[0, :] = px
        initial_states_matrix[1, :] = py
        initial_states_matrix[4, :] = theta
        initial_states_matrix[2, :] = V_CONST * np.cos(theta)
        initial_states_matrix[3, :] = V_CONST * np.sin(theta)

        all_pairs_safe = True
        for i in range(N_AGENTS):
            for j in range(i + 1, N_AGENTS):
                p_i = initial_states_matrix[0:2, i]
                p_j = initial_states_matrix[0:2, j]
                v_i = initial_states_matrix[2:4, i]
                v_j = initial_states_matrix[2:4, j]

                p_ij = p_i - p_j
                v_ij = v_i - v_j

                pij_norm = np.linalg.norm(p_ij)
                vij_norm = np.linalg.norm(v_ij)
                pv_dot = np.dot(p_ij, v_ij)

                if pij_norm <= critical_distance * 1.5:
                    all_pairs_safe = False
                    break

                # pij_norm > 1.5 * critical implies disc > 0 and h_ds > 0 automatically,
                # so we only compute disc / sqrt_term for VO / FVO expressions below.
                disc = pij_norm**2 - critical_distance**2
                sqrt_term = np.sqrt(disc)

                h_vo = pv_dot + vij_norm * sqrt_term - margin
                if h_vo < 0:
                    all_pairs_safe = False
                    break

                if pij_norm * vij_norm <= 2 * V_CONST * sqrt_term:
                    h_fvo = (pv_dot
                             + (pij_norm / (4 * V_CONST)) * vij_norm**2
                             + V_CONST * pij_norm
                             - V_CONST * critical_distance**2 / pij_norm
                             - margin)
                else:
                    h_fvo = h_vo
                if h_fvo < 0:
                    all_pairs_safe = False
                    break

                h1 = disc
                psi1 = 2 * pv_dot + class_k1 * h1   # psi_1 = L_f h + alpha_1 * h
                if psi1 < 0:
                    all_pairs_safe = False
                    break


            if not all_pairs_safe:
                break

        if all_pairs_safe:
            return initial_states_matrix

    raise RuntimeError(f"Could not find safe initial conditions after {max_attempts} attempts.")

# %%
# --- Shared parameters (identical across all cases) ---
V_CONST = 20.0
STATE_DIM = 5

# CBF parameters (used by create_safe_initial_conditions)
class_k1 = 0.1
class_k2 = 0.1
margin = 1e-4
k_vo = 1000.0

# Number of initial conditions per case
test_case_num = 100

# %%
np.save('parameter/V_CONST.npy', V_CONST)
np.save('parameter/STATE_DIM.npy', STATE_DIM)
np.save('parameter/class_k1.npy', class_k1)
np.save('parameter/class_k2.npy', class_k2)
np.save('parameter/margin.npy', margin)
np.save('parameter/k_vo.npy', k_vo)
np.save('parameter/test_case_num.npy', test_case_num)

# %%
# --- Group C: Desired-distance sweep (N=10, critical=40) ---
# Cases: (case_id, N_AGENTS, desired_distance, critical_distance)
CASES = [
    ('case0_d50', 15, 60, 40),
    ('case1_d60', 15, 70, 40),
    ('case2_d70', 15, 80, 40),
    ('case3_d80', 15, 90, 40),
    ('case4_d90', 15, 100, 40),
]

#CASES = [
#    ('case0_d50', 15, 50, 40),
#    ('case1_d60', 15, 60, 40),
#    ('case2_d70', 15, 70, 40),
#    ('case3_d80', 15, 80, 40),
#]

# Base retry parameters
max_widen = 10
widen_factor = 1.2

cases_manifest = []
for case_id, N_AGENTS, desired_distance, critical_distance in CASES:
    print(f'\n==== {case_id} (N={N_AGENTS}, desired={desired_distance}, critical={critical_distance}) ====')

    # Per-case parameter save
    os.makedirs(f'parameter/{case_id}', exist_ok=True)
    np.save(f'parameter/{case_id}/N_AGENTS.npy', N_AGENTS)
    np.save(f'parameter/{case_id}/desired_distance.npy', desired_distance)
    np.save(f'parameter/{case_id}/critical_distance.npy', critical_distance)

    # Adaptive base_range — wider for larger N since HO constraint tightens
    if N_AGENTS >= 20:
        base_range = 1000.0
    elif N_AGENTS >= 15:
        base_range = 500.0
    else:
        base_range = 500.0
    print(f'  [{case_id}] base_range = ±{base_range:.0f}')
    # Generate initial conditions
    initial_test_case = np.zeros((STATE_DIM, N_AGENTS, test_case_num))
    for tc in range(test_case_num):
        current_range = base_range
        for widen_iter in range(max_widen + 1):
            try:
                initial_test_case[:, :, tc] = create_safe_initial_conditions(
                    N_AGENTS, V_CONST, critical_distance, desired_distance,
                    margin, class_k1, class_k2,
                    position_range=(-current_range, current_range),
                    max_attempts=10000,
                )
                break
            except RuntimeError:
                if widen_iter < max_widen:
                    current_range *= widen_factor
                    print(f'  [{case_id}] tc={tc}: widening range to ±{current_range:.0f}')
                else:
                    raise RuntimeError(f'{case_id}: tc={tc} infeasible after {max_widen} widenings')
        if (tc + 1) % 10 == 0:
            print(f'  [{case_id}] {tc+1}/{test_case_num} generated')

    # Save initial conditions
    os.makedirs(f'initial_conditions/{case_id}', exist_ok=True)
    np.save(f'initial_conditions/{case_id}/initial.npy', initial_test_case)
    cases_manifest.append({'case_id': case_id, 'N_AGENTS': N_AGENTS, 'desired_distance': desired_distance, 'critical_distance': critical_distance})
    print(f'  -> initial_conditions/{case_id}/initial.npy saved (shape={initial_test_case.shape})')

# Write cases manifest for run_all.sh to consume
with open('cases.json', 'w') as f:
    json.dump(cases_manifest, f, indent=2)
print('\nAll cases generated and cases.json written.')
# Out:
# ==== case0_d50 (N=15, desired=60, critical=40) ====
#   [case0_d50] base_range = ±500
#   [case0_d50] tc=0: widening range to ±600
#   [case0_d50] tc=0: widening range to ±720
#   [case0_d50] tc=1: widening range to ±600
#   [case0_d50] tc=1: widening range to ±720
#   [case0_d50] tc=1: widening range to ±864
#   [case0_d50] tc=2: widening range to ±600
#   [case0_d50] tc=2: widening range to ±720
#   [case0_d50] tc=2: widening range to ±864
#   [case0_d50] tc=3: widening range to ±600
#   [case0_d50] tc=3: widening range to ±720
#   [case0_d50] tc=5: widening range to ±600
#   [case0_d50] tc=5: widening range to ±720
#   [case0_d50] tc=6: widening range to ±600
#   [case0_d50] tc=6: widening range to ±720
#   [case0_d50] tc=7: widening range to ±600
#   [case0_d50] tc=7: widening range to ±720
#   [case0_d50] tc=7: widening range to ±864
#   [case0_d50] tc=8: widening range to ±600
#   [case0_d50] tc=8: widening range to ±720
#   [case0_d50] tc=8: widening range to ±864
#   [case0_d50] tc=9: widening range to ±600
#   [case0_d50] tc=9: widening range to ±720
#   [case0_d50] tc=9: widening range to ±864
#   [case0_d50] 10/100 generated
#   [case0_d50] tc=10: widening range to ±600
#   [case0_d50] tc=10: widening range to ±720
#   [case0_d50] tc=10: widening range to ±864
#   [case0_d50] tc=11: widening range to ±600
#   [case0_d50] tc=11: widening range to ±720
#   [case0_d50] tc=12: widening range to ±600
#   [case0_d50] tc=12: widening range to ±720
#   [case0_d50] tc=12: widening range to ±864
#   [case0_d50] tc=13: widening range to ±600
#   [case0_d50] tc=13: widening range to ±720
#   [case0_d50] tc=13: widening range to ±864
#   [case0_d50] tc=14: widening range to ±600
#   [case0_d50] tc=14: widening range to ±720
#   [case0_d50] tc=14: widening range to ±864
#   [case0_d50] tc=15: widening range to ±600
#   [case0_d50] tc=15: widening range to ±720
#   [case0_d50] tc=16: widening range to ±600
#   [case0_d50] tc=16: widening range to ±720
#   [case0_d50] tc=16: widening range to ±864
#   [case0_d50] tc=17: widening range to ±600
#   [case0_d50] tc=17: widening range to ±720
#   [case0_d50] tc=18: widening range to ±600
#   [case0_d50] tc=18: widening range to ±720
#   [case0_d50] tc=18: widening range to ±864
#   [case0_d50] tc=19: widening range to ±600
#   [case0_d50] tc=19: widening range to ±720
#   [case0_d50] tc=19: widening range to ±864
#   [case0_d50] 20/100 generated
#   [case0_d50] tc=20: widening range to ±600
#   [case0_d50] tc=20: widening range to ±720
#   [case0_d50] tc=21: widening range to ±600
#   [case0_d50] tc=21: widening range to ±720
#   [case0_d50] tc=21: widening range to ±864
#   [case0_d50] tc=22: widening range to ±600
#   [case0_d50] tc=22: widening range to ±720
#   [case0_d50] tc=22: widening range to ±864
#   [case0_d50] tc=23: widening range to ±600
#   [case0_d50] tc=23: widening range to ±720
#   [case0_d50] tc=24: widening range to ±600
#   [case0_d50] tc=25: widening range to ±600
#   [case0_d50] tc=25: widening range to ±720
#   [case0_d50] tc=25: widening range to ±864
#   [case0_d50] tc=26: widening range to ±600
#   [case0_d50] tc=26: widening range to ±720
#   [case0_d50] tc=26: widening range to ±864
#   [case0_d50] tc=27: widening range to ±600
#   [case0_d50] tc=27: widening range to ±720
#   [case0_d50] tc=27: widening range to ±864
#   [case0_d50] tc=28: widening range to ±600
#   [case0_d50] tc=28: widening range to ±720
#   [case0_d50] tc=29: widening range to ±600
#   [case0_d50] tc=29: widening range to ±720
#   [case0_d50] 30/100 generated
#   [case0_d50] tc=30: widening range to ±600
#   [case0_d50] tc=30: widening range to ±720
#   [case0_d50] tc=31: widening range to ±600
#   [case0_d50] tc=31: widening range to ±720
#   [case0_d50] tc=31: widening range to ±864
#   [case0_d50] tc=32: widening range to ±600
#   [case0_d50] tc=32: widening range to ±720
#   [case0_d50] tc=32: widening range to ±864
#   [case0_d50] tc=33: widening range to ±600
#   [case0_d50] tc=33: widening range to ±720
#   [case0_d50] tc=34: widening range to ±600
#   [case0_d50] tc=34: widening range to ±720
#   [case0_d50] tc=35: widening range to ±600
#   [case0_d50] tc=35: widening range to ±720
#   [case0_d50] tc=36: widening range to ±600
#   [case0_d50] tc=36: widening range to ±720
#   [case0_d50] tc=37: widening range to ±600
#   [case0_d50] tc=38: widening range to ±600
#   [case0_d50] tc=38: widening range to ±720
#   [case0_d50] tc=38: widening range to ±864
#   [case0_d50] tc=39: widening range to ±600
#   [case0_d50] tc=39: widening range to ±720
#   [case0_d50] 40/100 generated
#   [case0_d50] tc=40: widening range to ±600
#   [case0_d50] tc=40: widening range to ±720
#   [case0_d50] tc=40: widening range to ±864
#   [case0_d50] tc=41: widening range to ±600
#   [case0_d50] tc=41: widening range to ±720
#   [case0_d50] tc=42: widening range to ±600
#   [case0_d50] tc=42: widening range to ±720
#   [case0_d50] tc=42: widening range to ±864
#   [case0_d50] tc=43: widening range to ±600
#   [case0_d50] tc=43: widening range to ±720
#   [case0_d50] tc=44: widening range to ±600
#   [case0_d50] tc=44: widening range to ±720
#   [case0_d50] tc=45: widening range to ±600
#   [case0_d50] tc=45: widening range to ±720
#   [case0_d50] tc=46: widening range to ±600
#   [case0_d50] tc=46: widening range to ±720
#   [case0_d50] tc=46: widening range to ±864
#   [case0_d50] tc=47: widening range to ±600
#   [case0_d50] tc=47: widening range to ±720
#   [case0_d50] tc=47: widening range to ±864
#   [case0_d50] tc=48: widening range to ±600
#   [case0_d50] tc=48: widening range to ±720
#   [case0_d50] tc=49: widening range to ±600
#   [case0_d50] tc=49: widening range to ±720
#   [case0_d50] 50/100 generated
#   [case0_d50] tc=50: widening range to ±600
#   [case0_d50] tc=50: widening range to ±720
#   [case0_d50] tc=50: widening range to ±864
#   [case0_d50] tc=51: widening range to ±600
#   [case0_d50] tc=51: widening range to ±720
#   [case0_d50] tc=51: widening range to ±864
#   [case0_d50] tc=52: widening range to ±600
#   [case0_d50] tc=52: widening range to ±720
#   [case0_d50] tc=53: widening range to ±600
#   [case0_d50] tc=53: widening range to ±720
#   [case0_d50] tc=54: widening range to ±600
#   [case0_d50] tc=54: widening range to ±720
#   [case0_d50] tc=55: widening range to ±600
#   [case0_d50] tc=55: widening range to ±720
#   [case0_d50] tc=55: widening range to ±864
#   [case0_d50] tc=56: widening range to ±600
#   [case0_d50] tc=56: widening range to ±720
#   [case0_d50] tc=57: widening range to ±600
#   [case0_d50] tc=57: widening range to ±720
#   [case0_d50] tc=58: widening range to ±600
#   [case0_d50] tc=58: widening range to ±720
#   [case0_d50] tc=59: widening range to ±600
#   [case0_d50] tc=59: widening range to ±720
#   [case0_d50] 60/100 generated
#   [case0_d50] tc=60: widening range to ±600
#   [case0_d50] tc=60: widening range to ±720
#   [case0_d50] tc=61: widening range to ±600
#   [case0_d50] tc=61: widening range to ±720
#   [case0_d50] tc=62: widening range to ±600
#   [case0_d50] tc=62: widening range to ±720
#   [case0_d50] tc=63: widening range to ±600
#   [case0_d50] tc=63: widening range to ±720
#   [case0_d50] tc=64: widening range to ±600
#   [case0_d50] tc=65: widening range to ±600
#   [case0_d50] tc=65: widening range to ±720
#   [case0_d50] tc=65: widening range to ±864
#   [case0_d50] tc=66: widening range to ±600
#   [case0_d50] tc=66: widening range to ±720
#   [case0_d50] tc=67: widening range to ±600
#   [case0_d50] tc=67: widening range to ±720
#   [case0_d50] tc=68: widening range to ±600
#   [case0_d50] tc=68: widening range to ±720
#   [case0_d50] tc=68: widening range to ±864
#   [case0_d50] tc=69: widening range to ±600
#   [case0_d50] tc=69: widening range to ±720
#   [case0_d50] 70/100 generated
#   [case0_d50] tc=70: widening range to ±600
#   [case0_d50] tc=70: widening range to ±720
#   [case0_d50] tc=70: widening range to ±864
#   [case0_d50] tc=71: widening range to ±600
#   [case0_d50] tc=71: widening range to ±720
#   [case0_d50] tc=71: widening range to ±864
#   [case0_d50] tc=72: widening range to ±600
#   [case0_d50] tc=72: widening range to ±720
#   [case0_d50] tc=73: widening range to ±600
#   [case0_d50] tc=73: widening range to ±720
#   [case0_d50] tc=74: widening range to ±600
#   [case0_d50] tc=74: widening range to ±720
#   [case0_d50] tc=74: widening range to ±864
#   [case0_d50] tc=75: widening range to ±600
#   [case0_d50] tc=75: widening range to ±720
#   [case0_d50] tc=75: widening range to ±864
#   [case0_d50] tc=76: widening range to ±600
#   [case0_d50] tc=76: widening range to ±720
#   [case0_d50] tc=77: widening range to ±600
#   [case0_d50] tc=77: widening range to ±720
#   [case0_d50] tc=78: widening range to ±600
#   [case0_d50] tc=78: widening range to ±720
#   [case0_d50] tc=78: widening range to ±864
#   [case0_d50] tc=79: widening range to ±600
#   [case0_d50] tc=79: widening range to ±720
#   [case0_d50] tc=79: widening range to ±864
#   [case0_d50] 80/100 generated
#   [case0_d50] tc=80: widening range to ±600
#   [case0_d50] tc=81: widening range to ±600
#   [case0_d50] tc=82: widening range to ±600
#   [case0_d50] tc=82: widening range to ±720
#   [case0_d50] tc=83: widening range to ±600
#   [case0_d50] tc=84: widening range to ±600
#   [case0_d50] tc=84: widening range to ±720
#   [case0_d50] tc=85: widening range to ±600
#   [case0_d50] tc=85: widening range to ±720
#   [case0_d50] tc=85: widening range to ±864
#   [case0_d50] tc=86: widening range to ±600
#   [case0_d50] tc=86: widening range to ±720
#   [case0_d50] tc=87: widening range to ±600
#   [case0_d50] tc=87: widening range to ±720
#   [case0_d50] tc=88: widening range to ±600
#   [case0_d50] tc=88: widening range to ±720
#   [case0_d50] tc=89: widening range to ±600
#   [case0_d50] tc=89: widening range to ±720
#   [case0_d50] 90/100 generated
#   [case0_d50] tc=90: widening range to ±600
#   [case0_d50] tc=90: widening range to ±720
#   [case0_d50] tc=90: widening range to ±864
#   [case0_d50] tc=91: widening range to ±600
#   [case0_d50] tc=91: widening range to ±720
#   [case0_d50] tc=92: widening range to ±600
#   [case0_d50] tc=92: widening range to ±720
#   [case0_d50] tc=92: widening range to ±864
#   [case0_d50] tc=93: widening range to ±600
#   [case0_d50] tc=94: widening range to ±600
#   [case0_d50] tc=94: widening range to ±720
#   [case0_d50] tc=95: widening range to ±600
#   [case0_d50] tc=95: widening range to ±720
#   [case0_d50] tc=96: widening range to ±600
#   [case0_d50] tc=96: widening range to ±720
#   [case0_d50] tc=96: widening range to ±864
#   [case0_d50] tc=97: widening range to ±600
#   [case0_d50] tc=97: widening range to ±720
#   [case0_d50] tc=98: widening range to ±600
#   [case0_d50] tc=99: widening range to ±600
#   [case0_d50] tc=99: widening range to ±720
#   [case0_d50] 100/100 generated
#   -> initial_conditions/case0_d50/initial.npy saved (shape=(5, 15, 100))
#
# ==== case1_d60 (N=15, desired=70, critical=40) ====
#   [case1_d60] base_range = ±500
#   [case1_d60] tc=0: widening range to ±600
#   [case1_d60] tc=2: widening range to ±600
#   [case1_d60] tc=2: widening range to ±720
#   [case1_d60] tc=3: widening range to ±600
#   [case1_d60] tc=4: widening range to ±600
#   [case1_d60] tc=4: widening range to ±720
#   [case1_d60] tc=5: widening range to ±600
#   [case1_d60] tc=5: widening range to ±720
#   [case1_d60] tc=6: widening range to ±600
#   [case1_d60] tc=6: widening range to ±720
#   [case1_d60] tc=7: widening range to ±600
#   [case1_d60] tc=7: widening range to ±720
#   [case1_d60] tc=7: widening range to ±864
#   [case1_d60] tc=8: widening range to ±600
#   [case1_d60] tc=8: widening range to ±720
#   [case1_d60] tc=8: widening range to ±864
#   [case1_d60] tc=9: widening range to ±600
#   [case1_d60] tc=9: widening range to ±720
#   [case1_d60] 10/100 generated
#   [case1_d60] tc=10: widening range to ±600
#   [case1_d60] tc=10: widening range to ±720
#   [case1_d60] tc=11: widening range to ±600
#   [case1_d60] tc=11: widening range to ±720
#   [case1_d60] tc=11: widening range to ±864
#   [case1_d60] tc=12: widening range to ±600
#   [case1_d60] tc=12: widening range to ±720
#   [case1_d60] tc=13: widening range to ±600
#   [case1_d60] tc=13: widening range to ±720
#   [case1_d60] tc=13: widening range to ±864
#   [case1_d60] tc=14: widening range to ±600
#   [case1_d60] tc=14: widening range to ±720
#   [case1_d60] tc=14: widening range to ±864
#   [case1_d60] tc=15: widening range to ±600
#   [case1_d60] tc=15: widening range to ±720
#   [case1_d60] tc=15: widening range to ±864
#   [case1_d60] tc=16: widening range to ±600
#   [case1_d60] tc=16: widening range to ±720
#   [case1_d60] tc=16: widening range to ±864
#   [case1_d60] tc=17: widening range to ±600
#   [case1_d60] tc=17: widening range to ±720
#   [case1_d60] tc=17: widening range to ±864
#   [case1_d60] tc=18: widening range to ±600
#   [case1_d60] tc=18: widening range to ±720
#   [case1_d60] tc=18: widening range to ±864
#   [case1_d60] tc=19: widening range to ±600
#   [case1_d60] 20/100 generated
#   [case1_d60] tc=20: widening range to ±600
#   [case1_d60] tc=20: widening range to ±720
#   [case1_d60] tc=21: widening range to ±600
#   [case1_d60] tc=21: widening range to ±720
#   [case1_d60] tc=21: widening range to ±864
#   [case1_d60] tc=22: widening range to ±600
#   [case1_d60] tc=22: widening range to ±720
#   [case1_d60] tc=22: widening range to ±864
#   [case1_d60] tc=23: widening range to ±600
#   [case1_d60] tc=23: widening range to ±720
#   [case1_d60] tc=23: widening range to ±864
#   [case1_d60] tc=24: widening range to ±600
#   [case1_d60] tc=24: widening range to ±720
#   [case1_d60] tc=24: widening range to ±864
#   [case1_d60] tc=25: widening range to ±600
#   [case1_d60] tc=25: widening range to ±720
#   [case1_d60] tc=26: widening range to ±600
#   [case1_d60] tc=26: widening range to ±720
#   [case1_d60] tc=26: widening range to ±864
#   [case1_d60] tc=27: widening range to ±600
#   [case1_d60] tc=27: widening range to ±720
#   [case1_d60] tc=28: widening range to ±600
#   [case1_d60] tc=28: widening range to ±720
#   [case1_d60] tc=29: widening range to ±600
#   [case1_d60] tc=29: widening range to ±720
#   [case1_d60] 30/100 generated
#   [case1_d60] tc=30: widening range to ±600
#   [case1_d60] tc=30: widening range to ±720
#   [case1_d60] tc=31: widening range to ±600
#   [case1_d60] tc=31: widening range to ±720
#   [case1_d60] tc=32: widening range to ±600
#   [case1_d60] tc=32: widening range to ±720
#   [case1_d60] tc=32: widening range to ±864
#   [case1_d60] tc=33: widening range to ±600
#   [case1_d60] tc=33: widening range to ±720
#   [case1_d60] tc=33: widening range to ±864
#   [case1_d60] tc=34: widening range to ±600
#   [case1_d60] tc=34: widening range to ±720
#   [case1_d60] tc=35: widening range to ±600
#   [case1_d60] tc=35: widening range to ±720
#   [case1_d60] tc=35: widening range to ±864
#   [case1_d60] tc=36: widening range to ±600
#   [case1_d60] tc=36: widening range to ±720
#   [case1_d60] tc=36: widening range to ±864
#   [case1_d60] tc=37: widening range to ±600
#   [case1_d60] tc=37: widening range to ±720
#   [case1_d60] tc=37: widening range to ±864
#   [case1_d60] tc=38: widening range to ±600
#   [case1_d60] tc=38: widening range to ±720
#   [case1_d60] tc=39: widening range to ±600
#   [case1_d60] tc=39: widening range to ±720
#   [case1_d60] 40/100 generated
#   [case1_d60] tc=40: widening range to ±600
#   [case1_d60] tc=40: widening range to ±720
#   [case1_d60] tc=41: widening range to ±600
#   [case1_d60] tc=41: widening range to ±720
#   [case1_d60] tc=41: widening range to ±864
#   [case1_d60] tc=43: widening range to ±600
#   [case1_d60] tc=44: widening range to ±600
#   [case1_d60] tc=44: widening range to ±720
#   [case1_d60] tc=45: widening range to ±600
#   [case1_d60] tc=45: widening range to ±720
#   [case1_d60] tc=46: widening range to ±600
#   [case1_d60] tc=46: widening range to ±720
#   [case1_d60] tc=46: widening range to ±864
#   [case1_d60] tc=47: widening range to ±600
#   [case1_d60] tc=47: widening range to ±720
#   [case1_d60] tc=48: widening range to ±600
#   [case1_d60] tc=48: widening range to ±720
#   [case1_d60] tc=49: widening range to ±600
#   [case1_d60] tc=49: widening range to ±720
#   [case1_d60] tc=49: widening range to ±864
#   [case1_d60] 50/100 generated
#   [case1_d60] tc=50: widening range to ±600
#   [case1_d60] tc=50: widening range to ±720
#   [case1_d60] tc=50: widening range to ±864
#   [case1_d60] tc=51: widening range to ±600
#   [case1_d60] tc=52: widening range to ±600
#   [case1_d60] tc=52: widening range to ±720
#   [case1_d60] tc=53: widening range to ±600
#   [case1_d60] tc=53: widening range to ±720
#   [case1_d60] tc=53: widening range to ±864
#   [case1_d60] tc=54: widening range to ±600
#   [case1_d60] tc=54: widening range to ±720
#   [case1_d60] tc=55: widening range to ±600
#   [case1_d60] tc=55: widening range to ±720
#   [case1_d60] tc=55: widening range to ±864
#   [case1_d60] tc=56: widening range to ±600
#   [case1_d60] tc=57: widening range to ±600
#   [case1_d60] tc=57: widening range to ±720
#   [case1_d60] tc=58: widening range to ±600
#   [case1_d60] tc=58: widening range to ±720
#   [case1_d60] tc=59: widening range to ±600
#   [case1_d60] tc=59: widening range to ±720
#   [case1_d60] tc=59: widening range to ±864
#   [case1_d60] 60/100 generated
#   [case1_d60] tc=60: widening range to ±600
#   [case1_d60] tc=60: widening range to ±720
#   [case1_d60] tc=61: widening range to ±600
#   [case1_d60] tc=61: widening range to ±720
#   [case1_d60] tc=62: widening range to ±600
#   [case1_d60] tc=63: widening range to ±600
#   [case1_d60] tc=63: widening range to ±720
#   [case1_d60] tc=63: widening range to ±864
#   [case1_d60] tc=64: widening range to ±600
#   [case1_d60] tc=64: widening range to ±720
#   [case1_d60] tc=64: widening range to ±864
#   [case1_d60] tc=65: widening range to ±600
#   [case1_d60] tc=65: widening range to ±720
#   [case1_d60] tc=66: widening range to ±600
#   [case1_d60] tc=66: widening range to ±720
#   [case1_d60] tc=66: widening range to ±864
#   [case1_d60] tc=67: widening range to ±600
#   [case1_d60] tc=67: widening range to ±720
#   [case1_d60] tc=67: widening range to ±864
#   [case1_d60] tc=68: widening range to ±600
#   [case1_d60] tc=68: widening range to ±720
#   [case1_d60] tc=68: widening range to ±864
#   [case1_d60] tc=69: widening range to ±600
#   [case1_d60] tc=69: widening range to ±720
#   [case1_d60] 70/100 generated
#   [case1_d60] tc=70: widening range to ±600
#   [case1_d60] tc=70: widening range to ±720
#   [case1_d60] tc=70: widening range to ±864
#   [case1_d60] tc=71: widening range to ±600
#   [case1_d60] tc=71: widening range to ±720
#   [case1_d60] tc=71: widening range to ±864
#   [case1_d60] tc=72: widening range to ±600
#   [case1_d60] tc=72: widening range to ±720
#   [case1_d60] tc=72: widening range to ±864
#   [case1_d60] tc=73: widening range to ±600
#   [case1_d60] tc=73: widening range to ±720
#   [case1_d60] tc=74: widening range to ±600
#   [case1_d60] tc=74: widening range to ±720
#   [case1_d60] tc=75: widening range to ±600
#   [case1_d60] tc=75: widening range to ±720
#   [case1_d60] tc=75: widening range to ±864
#   [case1_d60] tc=76: widening range to ±600
#   [case1_d60] tc=76: widening range to ±720
#   [case1_d60] tc=77: widening range to ±600
#   [case1_d60] tc=78: widening range to ±600
#   [case1_d60] tc=79: widening range to ±600
#   [case1_d60] tc=79: widening range to ±720
#   [case1_d60] 80/100 generated
#   [case1_d60] tc=80: widening range to ±600
#   [case1_d60] tc=80: widening range to ±720
#   [case1_d60] tc=80: widening range to ±864
#   [case1_d60] tc=81: widening range to ±600
#   [case1_d60] tc=81: widening range to ±720
#   [case1_d60] tc=81: widening range to ±864
#   [case1_d60] tc=82: widening range to ±600
#   [case1_d60] tc=82: widening range to ±720
#   [case1_d60] tc=82: widening range to ±864
#   [case1_d60] tc=83: widening range to ±600
#   [case1_d60] tc=83: widening range to ±720
#   [case1_d60] tc=83: widening range to ±864
#   [case1_d60] tc=84: widening range to ±600
#   [case1_d60] tc=84: widening range to ±720
#   [case1_d60] tc=85: widening range to ±600
#   [case1_d60] tc=85: widening range to ±720
#   [case1_d60] tc=86: widening range to ±600
#   [case1_d60] tc=87: widening range to ±600
#   [case1_d60] tc=88: widening range to ±600
#   [case1_d60] tc=88: widening range to ±720
#   [case1_d60] tc=88: widening range to ±864
#   [case1_d60] tc=89: widening range to ±600
#   [case1_d60] tc=89: widening range to ±720
#   [case1_d60] 90/100 generated
#   [case1_d60] tc=90: widening range to ±600
#   [case1_d60] tc=90: widening range to ±720
#   [case1_d60] tc=90: widening range to ±864
#   [case1_d60] tc=91: widening range to ±600
#   [case1_d60] tc=91: widening range to ±720
#   [case1_d60] tc=93: widening range to ±600
#   [case1_d60] tc=93: widening range to ±720
#   [case1_d60] tc=93: widening range to ±864
#   [case1_d60] tc=94: widening range to ±600
#   [case1_d60] tc=94: widening range to ±720
#   [case1_d60] tc=94: widening range to ±864
#   [case1_d60] tc=95: widening range to ±600
#   [case1_d60] tc=95: widening range to ±720
#   [case1_d60] tc=96: widening range to ±600
#   [case1_d60] tc=96: widening range to ±720
#   [case1_d60] tc=96: widening range to ±864
#   [case1_d60] tc=97: widening range to ±600
#   [case1_d60] tc=97: widening range to ±720
#   [case1_d60] tc=97: widening range to ±864
#   [case1_d60] tc=98: widening range to ±600
#   [case1_d60] tc=98: widening range to ±720
#   [case1_d60] tc=99: widening range to ±600
#   [case1_d60] tc=99: widening range to ±720
#   [case1_d60] 100/100 generated
#   -> initial_conditions/case1_d60/initial.npy saved (shape=(5, 15, 100))
#
# ==== case2_d70 (N=15, desired=80, critical=40) ====
#   [case2_d70] base_range = ±500
#   [case2_d70] tc=0: widening range to ±600
#   [case2_d70] tc=0: widening range to ±720
#   [case2_d70] tc=1: widening range to ±600
#   [case2_d70] tc=1: widening range to ±720
#   [case2_d70] tc=1: widening range to ±864
#   [case2_d70] tc=2: widening range to ±600
#   [case2_d70] tc=2: widening range to ±720
#   [case2_d70] tc=3: widening range to ±600
#   [case2_d70] tc=3: widening range to ±720
#   [case2_d70] tc=3: widening range to ±864
#   [case2_d70] tc=4: widening range to ±600
#   [case2_d70] tc=4: widening range to ±720
#   [case2_d70] tc=4: widening range to ±864
#   [case2_d70] tc=5: widening range to ±600
#   [case2_d70] tc=6: widening range to ±600
#   [case2_d70] tc=6: widening range to ±720
#   [case2_d70] tc=6: widening range to ±864
#   [case2_d70] tc=7: widening range to ±600
#   [case2_d70] tc=7: widening range to ±720
#   [case2_d70] tc=7: widening range to ±864
#   [case2_d70] tc=8: widening range to ±600
#   [case2_d70] tc=8: widening range to ±720
#   [case2_d70] tc=9: widening range to ±600
#   [case2_d70] tc=9: widening range to ±720
#   [case2_d70] tc=9: widening range to ±864
#   [case2_d70] 10/100 generated
#   [case2_d70] tc=10: widening range to ±600
#   [case2_d70] tc=10: widening range to ±720
#   [case2_d70] tc=11: widening range to ±600
#   [case2_d70] tc=11: widening range to ±720
#   [case2_d70] tc=11: widening range to ±864
#   [case2_d70] tc=12: widening range to ±600
#   [case2_d70] tc=12: widening range to ±720
#   [case2_d70] tc=12: widening range to ±864
#   [case2_d70] tc=14: widening range to ±600
#   [case2_d70] tc=14: widening range to ±720
#   [case2_d70] tc=15: widening range to ±600
#   [case2_d70] tc=15: widening range to ±720
#   [case2_d70] tc=16: widening range to ±600
#   [case2_d70] tc=16: widening range to ±720
#   [case2_d70] tc=16: widening range to ±864
#   [case2_d70] tc=17: widening range to ±600
#   [case2_d70] tc=17: widening range to ±720
#   [case2_d70] tc=17: widening range to ±864
#   [case2_d70] tc=18: widening range to ±600
#   [case2_d70] tc=18: widening range to ±720
#   [case2_d70] tc=18: widening range to ±864
#   [case2_d70] tc=19: widening range to ±600
#   [case2_d70] tc=19: widening range to ±720
#   [case2_d70] tc=19: widening range to ±864
#   [case2_d70] 20/100 generated
#   [case2_d70] tc=20: widening range to ±600
#   [case2_d70] tc=20: widening range to ±720
#   [case2_d70] tc=20: widening range to ±864
#   [case2_d70] tc=21: widening range to ±600
#   [case2_d70] tc=21: widening range to ±720
#   [case2_d70] tc=22: widening range to ±600
#   [case2_d70] tc=22: widening range to ±720
#   [case2_d70] tc=23: widening range to ±600
#   [case2_d70] tc=23: widening range to ±720
#   [case2_d70] tc=24: widening range to ±600
#   [case2_d70] tc=24: widening range to ±720
#   [case2_d70] tc=25: widening range to ±600
#   [case2_d70] tc=25: widening range to ±720
#   [case2_d70] tc=26: widening range to ±600
#   [case2_d70] tc=26: widening range to ±720
#   [case2_d70] tc=27: widening range to ±600
#   [case2_d70] tc=27: widening range to ±720
#   [case2_d70] tc=27: widening range to ±864
#   [case2_d70] tc=28: widening range to ±600
#   [case2_d70] tc=28: widening range to ±720
#   [case2_d70] tc=28: widening range to ±864
#   [case2_d70] tc=29: widening range to ±600
#   [case2_d70] tc=29: widening range to ±720
#   [case2_d70] tc=29: widening range to ±864
#   [case2_d70] 30/100 generated
#   [case2_d70] tc=31: widening range to ±600
#   [case2_d70] tc=31: widening range to ±720
#   [case2_d70] tc=31: widening range to ±864
#   [case2_d70] tc=32: widening range to ±600
#   [case2_d70] tc=32: widening range to ±720
#   [case2_d70] tc=32: widening range to ±864
#   [case2_d70] tc=33: widening range to ±600
#   [case2_d70] tc=33: widening range to ±720
#   [case2_d70] tc=33: widening range to ±864
#   [case2_d70] tc=34: widening range to ±600
#   [case2_d70] tc=34: widening range to ±720
#   [case2_d70] tc=35: widening range to ±600
#   [case2_d70] tc=35: widening range to ±720
#   [case2_d70] tc=36: widening range to ±600
#   [case2_d70] tc=36: widening range to ±720
#   [case2_d70] tc=36: widening range to ±864
#   [case2_d70] tc=37: widening range to ±600
#   [case2_d70] tc=37: widening range to ±720
#   [case2_d70] tc=37: widening range to ±864
#   [case2_d70] tc=38: widening range to ±600
#   [case2_d70] tc=38: widening range to ±720
#   [case2_d70] tc=38: widening range to ±864
#   [case2_d70] tc=39: widening range to ±600
#   [case2_d70] 40/100 generated
#   [case2_d70] tc=40: widening range to ±600
#   [case2_d70] tc=40: widening range to ±720
#   [case2_d70] tc=40: widening range to ±864
#   [case2_d70] tc=41: widening range to ±600
#   [case2_d70] tc=41: widening range to ±720
#   [case2_d70] tc=42: widening range to ±600
#   [case2_d70] tc=43: widening range to ±600
#   [case2_d70] tc=43: widening range to ±720
#   [case2_d70] tc=44: widening range to ±600
#   [case2_d70] tc=44: widening range to ±720
#   [case2_d70] tc=45: widening range to ±600
#   [case2_d70] tc=45: widening range to ±720
#   [case2_d70] tc=45: widening range to ±864
#   [case2_d70] tc=46: widening range to ±600
#   [case2_d70] tc=47: widening range to ±600
#   [case2_d70] tc=48: widening range to ±600
#   [case2_d70] tc=48: widening range to ±720
#   [case2_d70] tc=49: widening range to ±600
#   [case2_d70] tc=49: widening range to ±720
#   [case2_d70] 50/100 generated
#   [case2_d70] tc=50: widening range to ±600
#   [case2_d70] tc=50: widening range to ±720
#   [case2_d70] tc=51: widening range to ±600
#   [case2_d70] tc=51: widening range to ±720
#   [case2_d70] tc=51: widening range to ±864
#   [case2_d70] tc=52: widening range to ±600
#   [case2_d70] tc=53: widening range to ±600
#   [case2_d70] tc=53: widening range to ±720
#   [case2_d70] tc=54: widening range to ±600
#   [case2_d70] tc=55: widening range to ±600
#   [case2_d70] tc=55: widening range to ±720
#   [case2_d70] tc=56: widening range to ±600
#   [case2_d70] tc=56: widening range to ±720
#   [case2_d70] tc=58: widening range to ±600
#   [case2_d70] tc=58: widening range to ±720
#   [case2_d70] tc=58: widening range to ±864
#   [case2_d70] tc=59: widening range to ±600
#   [case2_d70] tc=59: widening range to ±720
#   [case2_d70] tc=59: widening range to ±864
#   [case2_d70] 60/100 generated
#   [case2_d70] tc=60: widening range to ±600
#   [case2_d70] tc=60: widening range to ±720
#   [case2_d70] tc=60: widening range to ±864
#   [case2_d70] tc=61: widening range to ±600
#   [case2_d70] tc=61: widening range to ±720
#   [case2_d70] tc=62: widening range to ±600
#   [case2_d70] tc=62: widening range to ±720
#   [case2_d70] tc=63: widening range to ±600
#   [case2_d70] tc=63: widening range to ±720
#   [case2_d70] tc=63: widening range to ±864
#   [case2_d70] tc=64: widening range to ±600
#   [case2_d70] tc=64: widening range to ±720
#   [case2_d70] tc=65: widening range to ±600
#   [case2_d70] tc=65: widening range to ±720
#   [case2_d70] tc=66: widening range to ±600
#   [case2_d70] tc=66: widening range to ±720
#   [case2_d70] tc=66: widening range to ±864
#   [case2_d70] tc=67: widening range to ±600
#   [case2_d70] tc=67: widening range to ±720
#   [case2_d70] tc=68: widening range to ±600
#   [case2_d70] tc=68: widening range to ±720
#   [case2_d70] tc=69: widening range to ±600
#   [case2_d70] tc=69: widening range to ±720
#   [case2_d70] tc=69: widening range to ±864
#   [case2_d70] 70/100 generated
#   [case2_d70] tc=70: widening range to ±600
#   [case2_d70] tc=70: widening range to ±720
#   [case2_d70] tc=70: widening range to ±864
#   [case2_d70] tc=71: widening range to ±600
#   [case2_d70] tc=71: widening range to ±720
#   [case2_d70] tc=71: widening range to ±864
#   [case2_d70] tc=72: widening range to ±600
#   [case2_d70] tc=72: widening range to ±720
#   [case2_d70] tc=72: widening range to ±864
#   [case2_d70] tc=73: widening range to ±600
#   [case2_d70] tc=74: widening range to ±600
#   [case2_d70] tc=74: widening range to ±720
#   [case2_d70] tc=75: widening range to ±600
#   [case2_d70] tc=75: widening range to ±720
#   [case2_d70] tc=75: widening range to ±864
#   [case2_d70] tc=76: widening range to ±600
#   [case2_d70] tc=76: widening range to ±720
#   [case2_d70] tc=77: widening range to ±600
#   [case2_d70] tc=77: widening range to ±720
#   [case2_d70] tc=78: widening range to ±600
#   [case2_d70] tc=78: widening range to ±720
#   [case2_d70] tc=78: widening range to ±864
#   [case2_d70] tc=79: widening range to ±600
#   [case2_d70] 80/100 generated
#   [case2_d70] tc=80: widening range to ±600
#   [case2_d70] tc=80: widening range to ±720
#   [case2_d70] tc=80: widening range to ±864
#   [case2_d70] tc=81: widening range to ±600
#   [case2_d70] tc=82: widening range to ±600
#   [case2_d70] tc=82: widening range to ±720
#   [case2_d70] tc=82: widening range to ±864
#   [case2_d70] tc=83: widening range to ±600
#   [case2_d70] tc=83: widening range to ±720
#   [case2_d70] tc=83: widening range to ±864
#   [case2_d70] tc=83: widening range to ±1037
#   [case2_d70] tc=84: widening range to ±600
#   [case2_d70] tc=84: widening range to ±720
#   [case2_d70] tc=84: widening range to ±864
#   [case2_d70] tc=85: widening range to ±600
#   [case2_d70] tc=85: widening range to ±720
#   [case2_d70] tc=85: widening range to ±864
#   [case2_d70] tc=86: widening range to ±600
#   [case2_d70] tc=86: widening range to ±720
#   [case2_d70] tc=88: widening range to ±600
#   [case2_d70] tc=88: widening range to ±720
#   [case2_d70] tc=89: widening range to ±600
#   [case2_d70] tc=89: widening range to ±720
#   [case2_d70] tc=89: widening range to ±864
#   [case2_d70] 90/100 generated
#   [case2_d70] tc=90: widening range to ±600
#   [case2_d70] tc=90: widening range to ±720
#   [case2_d70] tc=91: widening range to ±600
#   [case2_d70] tc=91: widening range to ±720
#   [case2_d70] tc=92: widening range to ±600
#   [case2_d70] tc=92: widening range to ±720
#   [case2_d70] tc=92: widening range to ±864
#   [case2_d70] tc=93: widening range to ±600
#   [case2_d70] tc=93: widening range to ±720
#   [case2_d70] tc=93: widening range to ±864
#   [case2_d70] tc=94: widening range to ±600
#   [case2_d70] tc=94: widening range to ±720
#   [case2_d70] tc=94: widening range to ±864
#   [case2_d70] tc=95: widening range to ±600
#   [case2_d70] tc=95: widening range to ±720
#   [case2_d70] tc=96: widening range to ±600
#   [case2_d70] tc=96: widening range to ±720
#   [case2_d70] tc=96: widening range to ±864
#   [case2_d70] tc=97: widening range to ±600
#   [case2_d70] tc=97: widening range to ±720
#   [case2_d70] tc=97: widening range to ±864
#   [case2_d70] tc=98: widening range to ±600
#   [case2_d70] tc=99: widening range to ±600
#   [case2_d70] tc=99: widening range to ±720
#   [case2_d70] tc=99: widening range to ±864
#   [case2_d70] 100/100 generated
#   -> initial_conditions/case2_d70/initial.npy saved (shape=(5, 15, 100))
#
# ==== case3_d80 (N=15, desired=90, critical=40) ====
#   [case3_d80] base_range = ±500
#   [case3_d80] tc=0: widening range to ±600
#   [case3_d80] tc=0: widening range to ±720
#   [case3_d80] tc=1: widening range to ±600
#   [case3_d80] tc=1: widening range to ±720
#   [case3_d80] tc=2: widening range to ±600
#   [case3_d80] tc=2: widening range to ±720
#   [case3_d80] tc=2: widening range to ±864
#   [case3_d80] tc=3: widening range to ±600
#   [case3_d80] tc=3: widening range to ±720
#   [case3_d80] tc=3: widening range to ±864
#   [case3_d80] tc=4: widening range to ±600
#   [case3_d80] tc=4: widening range to ±720
#   [case3_d80] tc=4: widening range to ±864
#   [case3_d80] tc=5: widening range to ±600
#   [case3_d80] tc=5: widening range to ±720
#   [case3_d80] tc=6: widening range to ±600
#   [case3_d80] tc=6: widening range to ±720
#   [case3_d80] tc=7: widening range to ±600
#   [case3_d80] tc=7: widening range to ±720
#   [case3_d80] tc=8: widening range to ±600
#   [case3_d80] tc=8: widening range to ±720
#   [case3_d80] tc=9: widening range to ±600
#   [case3_d80] tc=9: widening range to ±720
#   [case3_d80] 10/100 generated
#   [case3_d80] tc=10: widening range to ±600
#   [case3_d80] tc=10: widening range to ±720
#   [case3_d80] tc=10: widening range to ±864
#   [case3_d80] tc=11: widening range to ±600
#   [case3_d80] tc=11: widening range to ±720
#   [case3_d80] tc=11: widening range to ±864
#   [case3_d80] tc=12: widening range to ±600
#   [case3_d80] tc=12: widening range to ±720
#   [case3_d80] tc=12: widening range to ±864
#   [case3_d80] tc=13: widening range to ±600
#   [case3_d80] tc=13: widening range to ±720
#   [case3_d80] tc=14: widening range to ±600
#   [case3_d80] tc=14: widening range to ±720
#   [case3_d80] tc=15: widening range to ±600
#   [case3_d80] tc=15: widening range to ±720
#   [case3_d80] tc=16: widening range to ±600
#   [case3_d80] tc=16: widening range to ±720
#   [case3_d80] tc=17: widening range to ±600
#   [case3_d80] tc=17: widening range to ±720
#   [case3_d80] tc=17: widening range to ±864
#   [case3_d80] tc=18: widening range to ±600
#   [case3_d80] tc=18: widening range to ±720
#   [case3_d80] tc=19: widening range to ±600
#   [case3_d80] tc=19: widening range to ±720
#   [case3_d80] tc=19: widening range to ±864
#   [case3_d80] 20/100 generated
#   [case3_d80] tc=20: widening range to ±600
#   [case3_d80] tc=20: widening range to ±720
#   [case3_d80] tc=21: widening range to ±600
#   [case3_d80] tc=21: widening range to ±720
#   [case3_d80] tc=21: widening range to ±864
#   [case3_d80] tc=22: widening range to ±600
#   [case3_d80] tc=22: widening range to ±720
#   [case3_d80] tc=23: widening range to ±600
#   [case3_d80] tc=23: widening range to ±720
#   [case3_d80] tc=23: widening range to ±864
#   [case3_d80] tc=23: widening range to ±1037
#   [case3_d80] tc=24: widening range to ±600
#   [case3_d80] tc=24: widening range to ±720
#   [case3_d80] tc=24: widening range to ±864
#   [case3_d80] tc=25: widening range to ±600
#   [case3_d80] tc=25: widening range to ±720
#   [case3_d80] tc=25: widening range to ±864
#   [case3_d80] tc=26: widening range to ±600
#   [case3_d80] tc=26: widening range to ±720
#   [case3_d80] tc=26: widening range to ±864
#   [case3_d80] tc=27: widening range to ±600
#   [case3_d80] tc=27: widening range to ±720
#   [case3_d80] tc=28: widening range to ±600
#   [case3_d80] tc=28: widening range to ±720
#   [case3_d80] tc=28: widening range to ±864
#   [case3_d80] 30/100 generated
#   [case3_d80] tc=30: widening range to ±600
#   [case3_d80] tc=30: widening range to ±720
#   [case3_d80] tc=31: widening range to ±600
#   [case3_d80] tc=31: widening range to ±720
#   [case3_d80] tc=32: widening range to ±600
#   [case3_d80] tc=32: widening range to ±720
#   [case3_d80] tc=32: widening range to ±864
#   [case3_d80] tc=33: widening range to ±600
#   [case3_d80] tc=33: widening range to ±720
#   [case3_d80] tc=33: widening range to ±864
#   [case3_d80] tc=34: widening range to ±600
#   [case3_d80] tc=34: widening range to ±720
#   [case3_d80] tc=34: widening range to ±864
#   [case3_d80] tc=34: widening range to ±1037
#   [case3_d80] tc=35: widening range to ±600
#   [case3_d80] tc=35: widening range to ±720
#   [case3_d80] tc=35: widening range to ±864
#   [case3_d80] tc=36: widening range to ±600
#   [case3_d80] tc=36: widening range to ±720
#   [case3_d80] tc=37: widening range to ±600
#   [case3_d80] tc=37: widening range to ±720
#   [case3_d80] tc=38: widening range to ±600
#   [case3_d80] tc=38: widening range to ±720
#   [case3_d80] tc=38: widening range to ±864
#   [case3_d80] tc=39: widening range to ±600
#   [case3_d80] tc=39: widening range to ±720
#   [case3_d80] 40/100 generated
#   [case3_d80] tc=40: widening range to ±600
#   [case3_d80] tc=40: widening range to ±720
#   [case3_d80] tc=41: widening range to ±600
#   [case3_d80] tc=41: widening range to ±720
#   [case3_d80] tc=42: widening range to ±600
#   [case3_d80] tc=42: widening range to ±720
#   [case3_d80] tc=43: widening range to ±600
#   [case3_d80] tc=44: widening range to ±600
#   [case3_d80] tc=44: widening range to ±720
#   [case3_d80] tc=45: widening range to ±600
#   [case3_d80] tc=45: widening range to ±720
#   [case3_d80] tc=45: widening range to ±864
#   [case3_d80] tc=46: widening range to ±600
#   [case3_d80] tc=47: widening range to ±600
#   [case3_d80] tc=47: widening range to ±720
#   [case3_d80] tc=47: widening range to ±864
#   [case3_d80] tc=48: widening range to ±600
#   [case3_d80] tc=48: widening range to ±720
#   [case3_d80] tc=49: widening range to ±600
#   [case3_d80] tc=49: widening range to ±720
#   [case3_d80] tc=49: widening range to ±864
#   [case3_d80] 50/100 generated
#   [case3_d80] tc=50: widening range to ±600
#   [case3_d80] tc=50: widening range to ±720
#   [case3_d80] tc=51: widening range to ±600
#   [case3_d80] tc=51: widening range to ±720
#   [case3_d80] tc=53: widening range to ±600
#   [case3_d80] tc=53: widening range to ±720
#   [case3_d80] tc=54: widening range to ±600
#   [case3_d80] tc=55: widening range to ±600
#   [case3_d80] tc=55: widening range to ±720
#   [case3_d80] tc=55: widening range to ±864
#   [case3_d80] tc=57: widening range to ±600
#   [case3_d80] tc=57: widening range to ±720
#   [case3_d80] tc=57: widening range to ±864
#   [case3_d80] tc=58: widening range to ±600
#   [case3_d80] tc=58: widening range to ±720
#   [case3_d80] tc=58: widening range to ±864
#   [case3_d80] tc=59: widening range to ±600
#   [case3_d80] tc=59: widening range to ±720
#   [case3_d80] tc=59: widening range to ±864
#   [case3_d80] 60/100 generated
#   [case3_d80] tc=60: widening range to ±600
#   [case3_d80] tc=60: widening range to ±720
#   [case3_d80] tc=61: widening range to ±600
#   [case3_d80] tc=61: widening range to ±720
#   [case3_d80] tc=62: widening range to ±600
#   [case3_d80] tc=62: widening range to ±720
#   [case3_d80] tc=62: widening range to ±864
#   [case3_d80] tc=63: widening range to ±600
#   [case3_d80] tc=63: widening range to ±720
#   [case3_d80] tc=64: widening range to ±600
#   [case3_d80] tc=65: widening range to ±600
#   [case3_d80] tc=65: widening range to ±720
#   [case3_d80] tc=66: widening range to ±600
#   [case3_d80] tc=66: widening range to ±720
#   [case3_d80] tc=66: widening range to ±864
#   [case3_d80] tc=67: widening range to ±600
#   [case3_d80] tc=67: widening range to ±720
#   [case3_d80] tc=68: widening range to ±600
#   [case3_d80] tc=68: widening range to ±720
#   [case3_d80] tc=68: widening range to ±864
#   [case3_d80] tc=69: widening range to ±600
#   [case3_d80] tc=69: widening range to ±720
#   [case3_d80] 70/100 generated
#   [case3_d80] tc=70: widening range to ±600
#   [case3_d80] tc=70: widening range to ±720
#   [case3_d80] tc=71: widening range to ±600
#   [case3_d80] tc=71: widening range to ±720
#   [case3_d80] tc=71: widening range to ±864
#   [case3_d80] tc=72: widening range to ±600
#   [case3_d80] tc=72: widening range to ±720
#   [case3_d80] tc=73: widening range to ±600
#   [case3_d80] tc=73: widening range to ±720
#   [case3_d80] tc=74: widening range to ±600
#   [case3_d80] tc=74: widening range to ±720
#   [case3_d80] tc=74: widening range to ±864
#   [case3_d80] tc=75: widening range to ±600
#   [case3_d80] tc=75: widening range to ±720
#   [case3_d80] tc=75: widening range to ±864
#   [case3_d80] tc=76: widening range to ±600
#   [case3_d80] tc=76: widening range to ±720
#   [case3_d80] tc=76: widening range to ±864
#   [case3_d80] tc=77: widening range to ±600
#   [case3_d80] tc=77: widening range to ±720
#   [case3_d80] tc=77: widening range to ±864
#   [case3_d80] tc=78: widening range to ±600
#   [case3_d80] tc=78: widening range to ±720
#   [case3_d80] tc=78: widening range to ±864
#   [case3_d80] tc=79: widening range to ±600
#   [case3_d80] tc=79: widening range to ±720
#   [case3_d80] tc=79: widening range to ±864
#   [case3_d80] 80/100 generated
#   [case3_d80] tc=80: widening range to ±600
#   [case3_d80] tc=80: widening range to ±720
#   [case3_d80] tc=80: widening range to ±864
#   [case3_d80] tc=81: widening range to ±600
#   [case3_d80] tc=81: widening range to ±720
#   [case3_d80] tc=82: widening range to ±600
#   [case3_d80] tc=82: widening range to ±720
#   [case3_d80] tc=83: widening range to ±600
#   [case3_d80] tc=83: widening range to ±720
#   [case3_d80] tc=83: widening range to ±864
#   [case3_d80] tc=84: widening range to ±600
#   [case3_d80] tc=84: widening range to ±720
#   [case3_d80] tc=85: widening range to ±600
#   [case3_d80] tc=85: widening range to ±720
#   [case3_d80] tc=85: widening range to ±864
#   [case3_d80] tc=86: widening range to ±600
#   [case3_d80] tc=86: widening range to ±720
#   [case3_d80] tc=87: widening range to ±600
#   [case3_d80] tc=87: widening range to ±720
#   [case3_d80] tc=88: widening range to ±600
#   [case3_d80] tc=89: widening range to ±600
#   [case3_d80] tc=89: widening range to ±720
#   [case3_d80] tc=89: widening range to ±864
#   [case3_d80] 90/100 generated
#   [case3_d80] tc=90: widening range to ±600
#   [case3_d80] tc=90: widening range to ±720
#   [case3_d80] tc=91: widening range to ±600
#   [case3_d80] tc=91: widening range to ±720
#   [case3_d80] tc=92: widening range to ±600
#   [case3_d80] tc=92: widening range to ±720
#   [case3_d80] tc=92: widening range to ±864
#   [case3_d80] tc=93: widening range to ±600
#   [case3_d80] tc=93: widening range to ±720
#   [case3_d80] tc=94: widening range to ±600
#   [case3_d80] tc=94: widening range to ±720
#   [case3_d80] tc=95: widening range to ±600
#   [case3_d80] tc=95: widening range to ±720
#   [case3_d80] tc=96: widening range to ±600
#   [case3_d80] tc=96: widening range to ±720
#   [case3_d80] tc=97: widening range to ±600
#   [case3_d80] tc=97: widening range to ±720
#   [case3_d80] tc=97: widening range to ±864
#   [case3_d80] tc=98: widening range to ±600
#   [case3_d80] tc=98: widening range to ±720
#   [case3_d80] tc=98: widening range to ±864
#   [case3_d80] tc=99: widening range to ±600
#   [case3_d80] tc=99: widening range to ±720
#   [case3_d80] tc=99: widening range to ±864
#   [case3_d80] 100/100 generated
#   -> initial_conditions/case3_d80/initial.npy saved (shape=(5, 15, 100))
#
# ==== case4_d90 (N=15, desired=100, critical=40) ====
#   [case4_d90] base_range = ±500
#   [case4_d90] tc=0: widening range to ±600
#   [case4_d90] tc=0: widening range to ±720
#   [case4_d90] tc=0: widening range to ±864
#   [case4_d90] tc=1: widening range to ±600
#   [case4_d90] tc=1: widening range to ±720
#   [case4_d90] tc=1: widening range to ±864
#   [case4_d90] tc=2: widening range to ±600
#   [case4_d90] tc=2: widening range to ±720
#   [case4_d90] tc=3: widening range to ±600
#   [case4_d90] tc=3: widening range to ±720
#   [case4_d90] tc=3: widening range to ±864
#   [case4_d90] tc=4: widening range to ±600
#   [case4_d90] tc=4: widening range to ±720
#   [case4_d90] tc=4: widening range to ±864
#   [case4_d90] tc=5: widening range to ±600
#   [case4_d90] tc=5: widening range to ±720
#   [case4_d90] tc=5: widening range to ±864
#   [case4_d90] tc=6: widening range to ±600
#   [case4_d90] tc=6: widening range to ±720
#   [case4_d90] tc=6: widening range to ±864
#   [case4_d90] tc=7: widening range to ±600
#   [case4_d90] tc=7: widening range to ±720
#   [case4_d90] tc=7: widening range to ±864
#   [case4_d90] tc=8: widening range to ±600
#   [case4_d90] tc=8: widening range to ±720
#   [case4_d90] tc=9: widening range to ±600
#   [case4_d90] tc=9: widening range to ±720
#   [case4_d90] tc=9: widening range to ±864
#   [case4_d90] 10/100 generated
#   [case4_d90] tc=10: widening range to ±600
#   [case4_d90] tc=11: widening range to ±600
#   [case4_d90] tc=11: widening range to ±720
#   [case4_d90] tc=12: widening range to ±600
#   [case4_d90] tc=13: widening range to ±600
#   [case4_d90] tc=13: widening range to ±720
#   [case4_d90] tc=14: widening range to ±600
#   [case4_d90] tc=14: widening range to ±720
#   [case4_d90] tc=14: widening range to ±864
#   [case4_d90] tc=15: widening range to ±600
#   [case4_d90] tc=15: widening range to ±720
#   [case4_d90] tc=15: widening range to ±864
#   [case4_d90] tc=16: widening range to ±600
#   [case4_d90] tc=17: widening range to ±600
#   [case4_d90] tc=17: widening range to ±720
#   [case4_d90] tc=17: widening range to ±864
#   [case4_d90] tc=18: widening range to ±600
#   [case4_d90] tc=18: widening range to ±720
#   [case4_d90] tc=18: widening range to ±864
#   [case4_d90] tc=19: widening range to ±600
#   [case4_d90] tc=19: widening range to ±720
#   [case4_d90] 20/100 generated
#   [case4_d90] tc=20: widening range to ±600
#   [case4_d90] tc=20: widening range to ±720
#   [case4_d90] tc=21: widening range to ±600
#   [case4_d90] tc=21: widening range to ±720
#   [case4_d90] tc=22: widening range to ±600
#   [case4_d90] tc=23: widening range to ±600
#   [case4_d90] tc=23: widening range to ±720
#   [case4_d90] tc=23: widening range to ±864
#   [case4_d90] tc=24: widening range to ±600
#   [case4_d90] tc=24: widening range to ±720
#   [case4_d90] tc=24: widening range to ±864
#   [case4_d90] tc=25: widening range to ±600
#   [case4_d90] tc=25: widening range to ±720
#   [case4_d90] tc=25: widening range to ±864
#   [case4_d90] tc=26: widening range to ±600
#   [case4_d90] tc=26: widening range to ±720
#   [case4_d90] tc=26: widening range to ±864
#   [case4_d90] tc=27: widening range to ±600
#   [case4_d90] tc=27: widening range to ±720
#   [case4_d90] tc=27: widening range to ±864
#   [case4_d90] tc=28: widening range to ±600
#   [case4_d90] tc=28: widening range to ±720
#   [case4_d90] tc=29: widening range to ±600
#   [case4_d90] tc=29: widening range to ±720
#   [case4_d90] 30/100 generated
#   [case4_d90] tc=30: widening range to ±600
#   [case4_d90] tc=30: widening range to ±720
#   [case4_d90] tc=31: widening range to ±600
#   [case4_d90] tc=31: widening range to ±720
#   [case4_d90] tc=31: widening range to ±864
#   [case4_d90] tc=32: widening range to ±600
#   [case4_d90] tc=32: widening range to ±720
#   [case4_d90] tc=32: widening range to ±864
#   [case4_d90] tc=33: widening range to ±600
#   [case4_d90] tc=33: widening range to ±720
#   [case4_d90] tc=33: widening range to ±864
#   [case4_d90] tc=34: widening range to ±600
#   [case4_d90] tc=34: widening range to ±720
#   [case4_d90] tc=35: widening range to ±600
#   [case4_d90] tc=36: widening range to ±600
#   [case4_d90] tc=36: widening range to ±720
#   [case4_d90] tc=36: widening range to ±864
#   [case4_d90] tc=37: widening range to ±600
#   [case4_d90] tc=38: widening range to ±600
#   [case4_d90] tc=38: widening range to ±720
#   [case4_d90] tc=38: widening range to ±864
#   [case4_d90] tc=39: widening range to ±600
#   [case4_d90] tc=39: widening range to ±720
#   [case4_d90] tc=39: widening range to ±864
#   [case4_d90] 40/100 generated
#   [case4_d90] tc=40: widening range to ±600
#   [case4_d90] tc=40: widening range to ±720
#   [case4_d90] tc=41: widening range to ±600
#   [case4_d90] tc=41: widening range to ±720
#   [case4_d90] tc=42: widening range to ±600
#   [case4_d90] tc=42: widening range to ±720
#   [case4_d90] tc=43: widening range to ±600
#   [case4_d90] tc=44: widening range to ±600
#   [case4_d90] tc=44: widening range to ±720
#   [case4_d90] tc=45: widening range to ±600
#   [case4_d90] tc=45: widening range to ±720
#   [case4_d90] tc=45: widening range to ±864
#   [case4_d90] tc=46: widening range to ±600
#   [case4_d90] tc=46: widening range to ±720
#   [case4_d90] tc=47: widening range to ±600
#   [case4_d90] tc=47: widening range to ±720
#   [case4_d90] tc=47: widening range to ±864
#   [case4_d90] tc=48: widening range to ±600
#   [case4_d90] tc=48: widening range to ±720
#   [case4_d90] tc=49: widening range to ±600
#   [case4_d90] tc=49: widening range to ±720
#   [case4_d90] tc=49: widening range to ±864
#   [case4_d90] 50/100 generated
#   [case4_d90] tc=50: widening range to ±600
#   [case4_d90] tc=50: widening range to ±720
#   [case4_d90] tc=51: widening range to ±600
#   [case4_d90] tc=51: widening range to ±720
#   [case4_d90] tc=51: widening range to ±864
#   [case4_d90] tc=52: widening range to ±600
#   [case4_d90] tc=52: widening range to ±720
#   [case4_d90] tc=53: widening range to ±600
#   [case4_d90] tc=53: widening range to ±720
#   [case4_d90] tc=53: widening range to ±864
#   [case4_d90] tc=54: widening range to ±600
#   [case4_d90] tc=54: widening range to ±720
#   [case4_d90] tc=55: widening range to ±600
#   [case4_d90] tc=55: widening range to ±720
#   [case4_d90] tc=56: widening range to ±600
#   [case4_d90] tc=56: widening range to ±720
#   [case4_d90] tc=57: widening range to ±600
#   [case4_d90] tc=57: widening range to ±720
#   [case4_d90] tc=58: widening range to ±600
#   [case4_d90] tc=58: widening range to ±720
#   [case4_d90] tc=58: widening range to ±864
#   [case4_d90] tc=59: widening range to ±600
#   [case4_d90] tc=59: widening range to ±720
#   [case4_d90] tc=59: widening range to ±864
#   [case4_d90] 60/100 generated
#   [case4_d90] tc=60: widening range to ±600
#   [case4_d90] tc=60: widening range to ±720
#   [case4_d90] tc=60: widening range to ±864
#   [case4_d90] tc=61: widening range to ±600
#   [case4_d90] tc=61: widening range to ±720
#   [case4_d90] tc=62: widening range to ±600
#   [case4_d90] tc=62: widening range to ±720
#   [case4_d90] tc=63: widening range to ±600
#   [case4_d90] tc=63: widening range to ±720
#   [case4_d90] tc=63: widening range to ±864
#   [case4_d90] tc=64: widening range to ±600
#   [case4_d90] tc=64: widening range to ±720
#   [case4_d90] tc=64: widening range to ±864
#   [case4_d90] tc=65: widening range to ±600
#   [case4_d90] tc=65: widening range to ±720
#   [case4_d90] tc=65: widening range to ±864
#   [case4_d90] tc=66: widening range to ±600
#   [case4_d90] tc=66: widening range to ±720
#   [case4_d90] tc=66: widening range to ±864
#   [case4_d90] tc=67: widening range to ±600
#   [case4_d90] tc=67: widening range to ±720
#   [case4_d90] tc=68: widening range to ±600
#   [case4_d90] tc=68: widening range to ±720
#   [case4_d90] tc=69: widening range to ±600
#   [case4_d90] tc=69: widening range to ±720
#   [case4_d90] 70/100 generated
#   [case4_d90] tc=70: widening range to ±600
#   [case4_d90] tc=70: widening range to ±720
#   [case4_d90] tc=70: widening range to ±864
#   [case4_d90] tc=71: widening range to ±600
#   [case4_d90] tc=71: widening range to ±720
#   [case4_d90] tc=72: widening range to ±600
#   [case4_d90] tc=72: widening range to ±720
#   [case4_d90] tc=72: widening range to ±864
#   [case4_d90] tc=73: widening range to ±600
#   [case4_d90] tc=73: widening range to ±720
#   [case4_d90] tc=74: widening range to ±600
#   [case4_d90] tc=74: widening range to ±720
#   [case4_d90] tc=75: widening range to ±600
#   [case4_d90] tc=75: widening range to ±720
#   [case4_d90] tc=75: widening range to ±864
#   [case4_d90] tc=76: widening range to ±600
#   [case4_d90] tc=76: widening range to ±720
#   [case4_d90] tc=76: widening range to ±864
#   [case4_d90] tc=77: widening range to ±600
#   [case4_d90] tc=77: widening range to ±720
#   [case4_d90] tc=77: widening range to ±864
#   [case4_d90] tc=78: widening range to ±600
#   [case4_d90] tc=78: widening range to ±720
#   [case4_d90] tc=78: widening range to ±864
#   [case4_d90] 80/100 generated
#   [case4_d90] tc=80: widening range to ±600
#   [case4_d90] tc=80: widening range to ±720
#   [case4_d90] tc=80: widening range to ±864
#   [case4_d90] tc=81: widening range to ±600
#   [case4_d90] tc=81: widening range to ±720
#   [case4_d90] tc=82: widening range to ±600
#   [case4_d90] tc=82: widening range to ±720
#   [case4_d90] tc=82: widening range to ±864
#   [case4_d90] tc=83: widening range to ±600
#   [case4_d90] tc=83: widening range to ±720
#   [case4_d90] tc=83: widening range to ±864
#   [case4_d90] tc=84: widening range to ±600
#   [case4_d90] tc=84: widening range to ±720
#   [case4_d90] tc=85: widening range to ±600
#   [case4_d90] tc=85: widening range to ±720
#   [case4_d90] tc=86: widening range to ±600
#   [case4_d90] tc=86: widening range to ±720
#   [case4_d90] tc=87: widening range to ±600
#   [case4_d90] tc=87: widening range to ±720
#   [case4_d90] tc=87: widening range to ±864
#   [case4_d90] tc=88: widening range to ±600
#   [case4_d90] tc=89: widening range to ±600
#   [case4_d90] tc=89: widening range to ±720
#   [case4_d90] tc=89: widening range to ±864
#   [case4_d90] 90/100 generated
#   [case4_d90] tc=90: widening range to ±600
#   [case4_d90] tc=90: widening range to ±720
#   [case4_d90] tc=91: widening range to ±600
#   [case4_d90] tc=92: widening range to ±600
#   [case4_d90] tc=92: widening range to ±720
#   [case4_d90] tc=92: widening range to ±864
#   [case4_d90] tc=93: widening range to ±600
#   [case4_d90] tc=93: widening range to ±720
#   [case4_d90] tc=93: widening range to ±864
#   [case4_d90] tc=94: widening range to ±600
#   [case4_d90] tc=94: widening range to ±720
#   [case4_d90] tc=95: widening range to ±600
#   [case4_d90] tc=95: widening range to ±720
#   [case4_d90] tc=96: widening range to ±600
#   [case4_d90] tc=97: widening range to ±600
#   [case4_d90] tc=98: widening range to ±600
#   [case4_d90] tc=98: widening range to ±720
#   [case4_d90] tc=99: widening range to ±600
#   [case4_d90] 100/100 generated
#   -> initial_conditions/case4_d90/initial.npy saved (shape=(5, 15, 100))
#
# All cases generated and cases.json written.
